# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

from sklearn.model_selection import train_test_split

# %%
# Importing the dataset from URL
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
df = pd.read_csv(url, header=0, parse_dates=[0], index_col=0)

# %%
# Splitting the data into train and test sets
train_data, test_data = train_test_split(df['Passengers'], test_size=0.2, shuffle=False)

# %%
# Fitting the ARIMA model
model = ARIMA(train_data, order=(2, 1, 2))
model_fit = model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
# Generate predictions
start_date = test_data.index[0]
end_date = test_data.index[-1]

print(start_date, end_date)
predictions = model_fit.predict(start=start_date, end=end_date, dynamic=False)
# Out:
# 1958-08-01 00:00:00 1960-12-01 00:00:00

# %%
# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Passengers'], label='Actual')
plt.plot(predictions.index, predictions, color='red', linestyle='--', label='Predicted')
plt.legend(loc='best')
plt.xlabel('Year')
plt.ylabel('Passenger Count')
plt.title('ARIMA Model - Air Passengers')
plt.show()

# %%
# mse
from sklearn.metrics import mean_squared_error
mean_squared_error(predictions, test_data)
# Out:
# 6808.3970474928465

# %%
import tqdm
z = 10
res = {}
cnt = 0
for i in range(z):
  for j in range(z):
    for k in range(z):
      cnt += 1
print(cnt)
# Out:
# 1000

# %%
min(res, key=res.get)
# Out:
# '0,2,7'

# %%
len(res)
# Out:
# 55

# %%
res
# Out:
# {'0,0,0': 46249.63074209567,
#  '0,0,1': 44249.28588793991,
#  '0,0,2': 42951.02122156218,
#  '0,0,3': 41631.04379595741,
#  '0,0,4': 42414.01348755327,
#  '0,0,5': 42456.12372530875,
#  '0,0,6': 41683.08640085895,
#  '0,0,7': 41586.34246788137,
#  '0,0,8': 42923.236837440185,
#  '0,0,9': 41367.24888964813,
#  '0,1,0': 8673.931034482759,
#  '0,1,1': 10215.151726093922,
#  '0,1,2': 7969.713538711266,
#  '0,1,3': 9487.053095166619,
#  '0,1,4': 6597.552916321548,
#  '0,1,5': 6711.684856745494,
#  '0,1,6': 7005.670697346613,
#  '0,1,7': 7205.118860842375,
#  '0,1,8': 8104.0325068295515,
#  '0,2,0': 986082.4827586284,
#  '0,2,1': 15117.383077572693,
#  '0,2,2': 18012.953205176203,
#  '0,2,3': 13385.805703740018,
#  '0,2,4': 16861.801721586195,
#  '0,2,5': 6381.504333613505,
#  '0,2,6': 4882.103828690684,
#  '0,2,7': 4351.021064314096,
#  '0,3,0': 5471343.724137571,
#  '0,3,1': 1166945.4041440892,
#  '0,3,2': 33865.226103365996,
#  '0,3,3': 48840.98726757844,
# ...
